# %% [markdown]
# <a href="https://colab.research.google.com/github/khanhduykl12/Buoi1_THDeepLearning/blob/main/Buoi1_ThDeepLrn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('titanic_disaster.csv')
pd.set_option("display.width", None)
print(df.head())
df
print(df.isnull().sum())
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])
df.drop('Cabin', axis=1, inplace=True)
print(df.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
Q1 = df['Fare'].quantile(0.25)
Q3 = df['Fare'].quantile(0.75)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR

df.loc[df['Fare'] > upper_limit, 'Fare'] = upper_limit

print(df['Fare'].describe())
# Out:
# count    891.000000
# mean      24.046813
# std       20.481625
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max       65.634400
# Name: Fare, dtype: float64

# %%
cols_to_check = ['Survived', 'Pclass', 'Sex', 'Embarked']

for col in cols_to_check:
    print(f"--- Kiểm tra cột: {col} ---")
    print(df[col].value_counts(normalize=True) * 100)
    print("\n")
# Out:
# --- Kiểm tra cột: Survived ---
# Survived
# 0    61.616162
# 1    38.383838
# Name: proportion, dtype: float64
#
#
# --- Kiểm tra cột: Pclass ---
# Pclass
# 3    55.106622
# 1    24.242424
# 2    20.650954
# Name: proportion, dtype: float64
#
#
# --- Kiểm tra cột: Sex ---
# Sex
# male      64.758698
# female    35.241302
# Name: proportion, dtype: float64
#
#
# --- Kiểm tra cột: Embarked ---
# Embarked
# S    72.502806
# C    18.855219
# Q     8.641975
# Name: proportion, dtype: float64
